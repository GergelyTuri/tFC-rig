# %% [markdown]
# # Notebook for plotting the trial and session data
# * 11/28/23 setup
# * 11/30/23 adding error handling

# %%
import matplotlib.pyplot as plt
import pandas as pd
import processing as pr

# %%
session = pr.Processing("test_data/74_5_2023-11-20_17-11-27_processed.json")
session_data = session.session_data
trials = session.trials

# %%
trial_df, t_type = session.prepropcess_trial("Trial_2")
trial_df.head()
t_type
# Out:
# '0'

# %%
session.plot_trial("Trial_2")
# Out:
# <Axes: title={'center': 'Trial#: Trial_2, Trial type: 0'}, xlabel='Time (s)', ylabel='Event (1 if Lick/Water Present)'>

# %%
fig, _ = session.plot_session()
# fig.savefig("session.png", bbox_inches='tight')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\code\tFC-rig\Software\processing_behavior\plot_trial_session.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/code/tFC-rig/Software/processing_behavior/plot_trial_session.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df
#
# NameError: name 'df' is not defined
